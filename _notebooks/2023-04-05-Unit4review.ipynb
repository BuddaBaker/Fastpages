# %% [markdown]
# # Unit 4 Review
# > Unit 4 Review

# %% [markdown]
# Processor GHz:
# Memory in GB:
# Storage in GB:
# OS:

# %% [markdown]
# Input devices - ![image.png](attachment:image.png)
# > Output devices - ![image.png](attachment:image-2.png)
# Program File - These are files that are used to run code, create code
# Program Code - Algorithms which are used toghether, in order to have an overall coding
# Processes- Running multiple services which run a certian program
# Ports - Different access points for services to run on.
# Data File - A file which is used to store the information of a running program. Usually a large file with lots of different cahracters and complicated languages.
# Inspect Running Code
# Inspect Variables
