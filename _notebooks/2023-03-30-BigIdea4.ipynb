# %% [markdown]
# # Big Idea #4
# > Big Idea #4

# %% [markdown]
# ![image.png](attachment:image.png)
#
# # Question 1
# ![image.png](attachment:image-2.png)
# The correct answer is C, The reason my answer is correct is incorrect is because it wouldn't be enough time to be able to run all the processes. The reason C is correct is because of how it will allow for enough time to have all the process run parrallel in enough time.
# # Question 6
# ![image.png](attachment:image-3.png)
# The Reason the answer is A is correct is because of how the data is sent with metadata which is retained even when an image is sent over the internet.
# # Question 8
# ![image.png](attachment:image-4.png)
# A and D are correct because for A: A simulation that shows how packets move between clients and servers can show the effects of temporarily unavailable network connections.
# for D:  A simulation that shows how packets move between clients and servers can demonstrate the impact of increased speeds for frequently-visited servers.
# # Question 16
# ![image.png](attachment:image-5.png)
# The reason the answer choice C is correct is because determining the topics for the scope of whats needed would a much better fit for the overall goals of the coding program.
# # Question 23
# ![image.png](attachment:image-6.png)
# The reason this answer choice is correct is because finding the 10 highest test scores isnt an example of finding a pattern so it would be the correct answer and satisfy the requirements of the question
# # Question 42
# ![image.png](attachment:image-7.png)
# The reason the answer choice is B is because the IsFound procedure will check both the files and accurately tell whether or not the word exists in both of the given files.
# # Question 44
# ![image.png](attachment:image-8.png)
# Procedural abstaction is demonstrated in answer choice C, because of how you don't need to know the value and you can search through the dictionary for the value you want.
# # Question 49
# ![image.png](attachment:image-9.png)
# The reason the answer choice A is correct is because of how it evaluates the first element, and the value which is chosen will skip the neccessary iterations making sure that the code segement runs correctly.

# %% [markdown]
# # Reflection
# Overall my test score on this was good, but could use significant improvement if I want to be successful for the AP exam.
