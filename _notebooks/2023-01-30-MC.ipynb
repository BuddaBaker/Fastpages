# %% [markdown]
# # MC
# > MC
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [Posts]
# - title: MC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The correct answer to this question would be B. The reason for position to be increased by 1 is to iterate through all the positons. If the position variable was not changed then the loop would run forever meaning that there would never be a display of the count which would be bad.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The answers to this question are B and C. The issue I had here was that I was careless when taking the test and only ended up selecting one of the answers. I was debating between whether to put B or C and didn't realize that I had to select two answers which is why I only selected one. In the future I will take more time to make sure I check my answers before submitting them.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The correct answer to this question was B not A. I put A because I thought both had to be set in order for the elevator to move. However the answer which was correct is B for the reason that setting either condition will make the elevator move. I was quite confused during this question, so I can work on taking more time to answer so my answers are also thoughtful and correct.

# %% [markdown]
# ![image.png](attachment:image.png)
# I was able to correctly identify A as the correct answer. I put B as the 2nd answer however it should have been D instead. The reason is because in D when you plug in a number to it, the result is always same regardless of what is put into it. In B the answer can vary based on what number is plugged in.

# %% [markdown]
# ![image.png](attachment:image.png)
# I was very confused during this question on the movement of the arrow. The if statements really confused me which is why I was unable to select the correct answer. Now looking at what is the correct answer I can understand why. If you just do what the code would do with the arrows you will end up with the result you want which is why it is the correct answer.

# %% [markdown]
# ![image.png](attachment:image.png)
# I was able to get the correct answer which was C however I missed the 2nd answer. The answer I put was D which is wrong because after you look at where it will go after 2 iterations the arrow will not be in the correct position. The correct is A because after the 4 iterations the arrow will be oriented in the correct way.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# I got the question partially correct by putting C. The other part was B where I put A, the key difference is where the circle is being drawn and after looking at it again, the correct answer makes sense to be B because in drawing the circle that way it will be what the diagram is rather than A which would different.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# The correct answer to this question would be B instead of C. The reasoning for C being wrong is that after the program is run, the robot cannot be positioned in a place where it is above the intial position. Answer B correctly accounts for all the possiblities that the robot could take.

# %% [markdown]
# ![image.png](attachment:image.png)
# The correct answer here was C and I made an oversight in putting the correct answer as A. The reason for me thinking it was A was because a simulation is difficult to design without real world of the object being there, however its possible. The simulation is just an assumption however which is why the correct answer would in fact be C.
