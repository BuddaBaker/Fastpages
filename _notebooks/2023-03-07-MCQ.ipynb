# %% [markdown]
# # MCQ Corrections
# > MCQ Corrections
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [Posts]
# - title: MCQ Corrections
# - layouts:base

# %% [markdown]
# ![image.png](attachment:image.png) Extra Seed

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Question 22
# ![image.png](attachment:image.png)
# The correct answer is A: Grid I. The reasoning behind this being the correct answer is that by running the code the robot will correctly orrient itself and complete the goal achieved accomplishments

# %% [markdown]
# # Question 33
# ![image.png](attachment:image.png)
# The correct answer to this question is B not D. The reason I put D is because I believed it was 4 times were needed for the robot to achieve the goal. The reason the answer is B is because after repeating the code 2 times then the robot will be in the gray square which is the overall goal of the problem.

# %% [markdown]
# # Question 40
# ![image.png](attachment:image.png)
# The correct answer was D not B like I put. The real reason I missed this question was that I was not reading through the question fully which caused me to skip over the correct answer. The reason this answer correct is because when moving the correct amount of places to the side and up then the function will correctly work as intended.

# %% [markdown]
# # Question 49
# ![image.png](attachment:image.png)
# The reason my answer for this question was incorrect was because I didnt correctly read the question which was needing there to be more understanding becuase I wanst fully able to grasp the concept that is mentioned in this question.

# %% [markdown]
# # Question 50
# ![image.png](attachment:image.png)
# My answer choices for this question were incorrect because one of the options wasn't fully the output that would be wanted to answer this question.

# %% [markdown]
# # Reflection
#
# Overall my performance was much better than I had on the last test which shows how the overall coding has helped with my coding understanding. The questions are tricky so that was the main reason for me missing the points that I missed throughout the test. Furthermore I should spend more time on making sure that
