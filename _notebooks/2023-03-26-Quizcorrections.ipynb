# %% [markdown]
# # Big Idea Quiz 2 and Corrections
# ![image.png](attachment:image-2.png)
# > Corrections
# Question 12:
# ![image.png](attachment:image.png)
# The mistake I made here was the answered I selected can actually be determined by analyzing the dates and times that trucks entered and left the depot.The reason answer choice B is correct is because the data collected each time a truck enters or exits does not include information about the number of customers or deliveries connected to the truck.
#
# Question 21:
# ![image.png](attachment:image-3.png)
# The reason answer choice C is wrong is this sequence of steps does not remove entries with unknown years, so the entry in the first row of the table has a year value of -1. Sorting by year will sort the spreadsheet on column C from slightest to most prominent. Sifting by year will expel any sections with obscure a long time. Sifting by picture taker will evacuate any passages with obscure picture takers. Since the arrange of the passages isn't influenced by the channels, the photo with the least year value will be within the to begin with push of the spreadsheet.
